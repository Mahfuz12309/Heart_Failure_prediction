# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahfuz12309/Heart_Failure_prediction/blob/main/heart_failure_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Mount drive and read dataset**

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
train = pd.read_csv('/content/drive/MyDrive/Ai research/Dataset/heart_failure_clinical_records_dataset.csv')

# %% [markdown]
# **Showing Dataset**

# %%
train.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  ...  smoking  time  DEATH_EVENT
# 0  75.0        0                       582  ...        0     4            1
# 1  55.0        0                      7861  ...        0     6            1
# 2  65.0        0                       146  ...        1     7            1
# 3  50.0        1                       111  ...        0     7            1
# 4  65.0        1                       160  ...        0     8            1
#
# [5 rows x 13 columns]

# %% [markdown]
# **DEATH EVENT**

# %%
train['DEATH_EVENT'].value_counts()
# Out:
# 0    203
# 1     96
# Name: DEATH_EVENT, dtype: int64

# %% [markdown]
# **INFO**

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %% [markdown]
# **Showing null Data**

# %%
train.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %% [markdown]
# **visualization**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %% [markdown]
# **Create a FUnction to see the graph**

# %%
def bar_chart(feature):
    survived = train[train['DEATH_EVENT']==0][feature].value_counts()
    dead = train[train['DEATH_EVENT']==1][feature].value_counts()
    df = pd.DataFrame([survived,dead])
    df.index = ['Survived','Dead']
    df.plot(kind='bar',stacked=True, figsize=(10,5))

# %%
bar_chart('age')

# %%
bar_chart('anaemia')

# %%
bar_chart('creatinine_phosphokinase')

# %%
bar_chart('diabetes')

# %%
bar_chart('ejection_fraction')

# %%
train.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  ...  smoking  time  DEATH_EVENT
# 0  75.0        0                       582  ...        0     4            1
# 1  55.0        0                      7861  ...        0     6            1
# 2  65.0        0                       146  ...        1     7            1
# 3  50.0        1                       111  ...        0     7            1
# 4  65.0        1                       160  ...        0     8            1
#
# [5 rows x 13 columns]

# %%
bar_chart('platelets')

# %%
bar_chart('age')

# %% [markdown]
# **Different age is existing. Divide in Catagorial Data**

# %%
facet = sns.FacetGrid(train, hue="DEATH_EVENT",aspect=4)
facet.map(sns.kdeplot,'age',shade= True)
facet.set(xlim=(0, train['age'].max()))
facet.add_legend()
plt.show()

# %%
facet = sns.FacetGrid(train, hue="DEATH_EVENT",aspect=4)
facet.map(sns.kdeplot,'age',shade= True)
facet.set(xlim=(0, train['age'].max()))
facet.add_legend()
plt.xlim(0,20)
# Out:
# (0.0, 20.0)

# %%
facet = sns.FacetGrid(train, hue="DEATH_EVENT",aspect=4)
facet.map(sns.kdeplot,'age',shade= True)
facet.set(xlim=(0, train['age'].max()))
facet.add_legend()
plt.xlim(20,30)
# Out:
# (20.0, 30.0)

# %%
facet = sns.FacetGrid(train, hue="DEATH_EVENT",aspect=4)
facet.map(sns.kdeplot,'age',shade= True)
facet.set(xlim=(0, train['age'].max()))
facet.add_legend()
plt.xlim(30,40)
# Out:
# (30.0, 40.0)

# %%
facet = sns.FacetGrid(train, hue="DEATH_EVENT",aspect=4)
facet.map(sns.kdeplot,'age',shade= True)
facet.set(xlim=(0, train['age'].max()))
facet.add_legend()
plt.xlim(40,50)
# Out:
# (40.0, 50.0)

# %%
facet = sns.FacetGrid(train, hue="DEATH_EVENT",aspect=4)
facet.map(sns.kdeplot,'age',shade= True)
facet.set(xlim=(0, train['age'].max()))
facet.add_legend()
plt.xlim(50,60)
# Out:
# (50.0, 60.0)

# %%
facet = sns.FacetGrid(train, hue="DEATH_EVENT",aspect=4)
facet.map(sns.kdeplot,'age',shade= True)
facet.set(xlim=(0, train['age'].max()))
facet.add_legend()
plt.xlim(60,70)
# Out:
# (60.0, 70.0)

# %%
facet = sns.FacetGrid(train, hue="DEATH_EVENT",aspect=4)
facet.map(sns.kdeplot,'age',shade= True)
facet.set(xlim=(0, train['age'].max()))
facet.add_legend()
plt.xlim(70,80)
# Out:
# (70.0, 80.0)

# %%
facet = sns.FacetGrid(train, hue="DEATH_EVENT",aspect=4)
facet.map(sns.kdeplot,'age',shade= True)
facet.set(xlim=(0, train['age'].max()))
facet.add_legend()
plt.xlim(80,90)
# Out:
# (80.0, 90.0)

# %%
facet = sns.FacetGrid(train, hue="DEATH_EVENT",aspect=4)
facet.map(sns.kdeplot,'age',shade= True)
facet.set(xlim=(0, train['age'].max()))
facet.add_legend()
plt.xlim(90,100)
# Out:
# (90.0, 100.0)

# %%
facet = sns.FacetGrid(train, hue="DEATH_EVENT",aspect=4)
facet.map(sns.kdeplot,'age',shade= True)
facet.set(xlim=(0, train['age'].max()))
facet.add_legend()
plt.xlim(100,120)
# Out:
# (100.0, 120.0)

# %%
train_test_data = [train]
for dataset in train_test_data:
    dataset.loc[ dataset['age'] <= 30, 'age'] = 0
    dataset.loc[(dataset['age'] > 30) & (dataset['age'] <= 40), 'age'] = 1
    dataset.loc[(dataset['age'] > 40) & (dataset['age'] <= 50), 'age'] = 2
    dataset.loc[(dataset['age'] > 50) & (dataset['age'] <= 60), 'age'] = 3
    dataset.loc[(dataset['age'] > 60) & (dataset['age'] <= 70), 'age'] = 4
    dataset.loc[(dataset['age'] > 70) & (dataset['age'] <= 80), 'age'] = 5
    dataset.loc[(dataset['age'] > 80) & (dataset['age'] <= 90), 'age'] = 6
    dataset.loc[(dataset['age'] > 90) & (dataset['age'] <= 100), 'age'] = 7
    dataset.loc[(dataset['age'] > 100) & (dataset['age'] <= 120), 'age'] = 8
    dataset.loc[ dataset['age'] > 120, 'age'] = 9

# %%
bar_chart('age')

# %%
train.head()
# Out:
#    age  anaemia  creatinine_phosphokinase  ...  smoking  time  DEATH_EVENT
# 0  5.0        0                       582  ...        0     4            1
# 1  3.0        0                      7861  ...        0     6            1
# 2  4.0        0                       146  ...        1     7            1
# 3  2.0        1                       111  ...        0     7            1
# 4  4.0        1                       160  ...        0     8            1
#
# [5 rows x 13 columns]

# %%
facet = sns.FacetGrid(train, hue="DEATH_EVENT",aspect=4)
facet.map(sns.kdeplot,'age',shade= True)
facet.set(xlim=(0, train['age'].max()))
facet.add_legend()
plt.show()

# %% [markdown]
# **Processing creatinine_phosphokinasea**

# %%
bar_chart('creatinine_phosphokinase')

# %% [markdown]
# **creatinine_phosphokinase in graph**

# %%
facet = sns.FacetGrid(train, hue="DEATH_EVENT",aspect=4)
facet.map(sns.kdeplot,'creatinine_phosphokinase',shade= True)
facet.set(xlim=(0, train['creatinine_phosphokinase'].max()))
facet.add_legend()
plt.show()

# %%
bar_chart('creatinine_phosphokinase')

# %%
facet = sns.FacetGrid(train, hue="DEATH_EVENT",aspect=4)
facet.map(sns.kdeplot,'creatinine_phosphokinase',shade= True)
facet.set(xlim=(0, train['creatinine_phosphokinase'].max()))
facet.add_legend()
plt.xlim(0,20)
# Out:
# (0.0, 20.0)

# %%
facet = sns.FacetGrid(train, hue="DEATH_EVENT",aspect=4)
facet.map(sns.kdeplot,'creatinine_phosphokinase',shade= True)
facet.set(xlim=(0, train['creatinine_phosphokinase'].max()))
facet.add_legend()
plt.xlim(20,40)
# Out:
# (20.0, 40.0)

# %%
facet = sns.FacetGrid(train, hue="DEATH_EVENT",aspect=4)
facet.map(sns.kdeplot,'creatinine_phosphokinase',shade= True)
facet.set(xlim=(0, train['creatinine_phosphokinase'].max()))
facet.add_legend()
plt.xlim(40,60)
# Out:
# (40.0, 60.0)

# %%
facet = sns.FacetGrid(train, hue="DEATH_EVENT",aspect=4)
facet.map(sns.kdeplot,'creatinine_phosphokinase',shade= True)
facet.set(xlim=(0, train['creatinine_phosphokinase'].max()))
facet.add_legend()
plt.xlim(60,80)
# Out:
# (60.0, 80.0)

# %%
train_test_data = [train]
for dataset in train_test_data:
    dataset.loc[ dataset['creatinine_phosphokinase'] <= 23, 'creatinine_phosphokinase'] = 0
    dataset.loc[(dataset['creatinine_phosphokinase'] > 23) & (dataset['creatinine_phosphokinase'] <= 50), 'creatinine_phosphokinase'] = 1
    dataset.loc[(dataset['creatinine_phosphokinase'] > 50) & (dataset['creatinine_phosphokinase'] <= 75), 'creatinine_phosphokinase'] = 2
    dataset.loc[(dataset['creatinine_phosphokinase'] > 75) & (dataset['creatinine_phosphokinase'] <= 100), 'creatinine_phosphokinase'] = 3
    dataset.loc[(dataset['creatinine_phosphokinase'] > 100) & (dataset['creatinine_phosphokinase'] <= 130), 'creatinine_phosphokinase'] = 4
    dataset.loc[(dataset['creatinine_phosphokinase'] > 130) & (dataset['creatinine_phosphokinase'] <= 160), 'creatinine_phosphokinase'] = 5
    dataset.loc[(dataset['creatinine_phosphokinase'] > 160) & (dataset['creatinine_phosphokinase'] <= 200), 'creatinine_phosphokinase'] = 6
    dataset.loc[(dataset['creatinine_phosphokinase'] > 200) & (dataset['creatinine_phosphokinase'] <= 250), 'creatinine_phosphokinase'] = 7
    dataset.loc[(dataset['creatinine_phosphokinase'] > 250) & (dataset['creatinine_phosphokinase'] <= 300), 'creatinine_phosphokinase'] = 8
    dataset.loc[(dataset['creatinine_phosphokinase'] > 300) & (dataset['creatinine_phosphokinase'] <= 350), 'creatinine_phosphokinase'] = 9
    dataset.loc[(dataset['creatinine_phosphokinase'] > 350) & (dataset['creatinine_phosphokinase'] <= 500), 'creatinine_phosphokinase'] = 10
    dataset.loc[(dataset['creatinine_phosphokinase'] > 500) & (dataset['creatinine_phosphokinase'] <= 750), 'creatinine_phosphokinase'] = 11
    dataset.loc[(dataset['creatinine_phosphokinase'] > 750) & (dataset['creatinine_phosphokinase'] <= 1000), 'creatinine_phosphokinase'] = 12
    dataset.loc[ dataset['creatinine_phosphokinase'] > 1000, 'creatinine_phosphokinase'] = 13

# %%
bar_chart('creatinine_phosphokinase')

# %%
train.head()
# Out:
#    age  anaemia  creatinine_phosphokinase  ...  smoking  time  DEATH_EVENT
# 0  5.0        0                        11  ...        0     4            1
# 1  3.0        0                        13  ...        0     6            1
# 2  4.0        0                         5  ...        1     7            1
# 3  2.0        1                         4  ...        0     7            1
# 4  4.0        1                         5  ...        0     8            1
#
# [5 rows x 13 columns]

# %%
bar_chart('ejection_fraction')

# %%
bar_chart('platelets')

# %% [markdown]
# **Catagorized platelets**

# %%
train_test_data = [train]
for dataset in train_test_data:
    dataset.loc[ dataset['platelets'] <= 25100, 'platelets'] = 0
    dataset.loc[(dataset['platelets'] > 25100) & (dataset['platelets'] <= 100000), 'platelets'] = 1
    dataset.loc[(dataset['platelets'] > 100000) & (dataset['platelets'] <= 150000), 'platelets'] = 2
    dataset.loc[(dataset['platelets'] > 150000) & (dataset['platelets'] <= 200000), 'platelets'] = 3
    dataset.loc[(dataset['platelets'] > 200000) & (dataset['platelets'] <= 250000), 'platelets'] = 4
    dataset.loc[(dataset['platelets'] > 250000) & (dataset['platelets'] <= 300000), 'platelets'] = 5
    dataset.loc[(dataset['platelets'] > 300000) & (dataset['platelets'] <= 400000), 'platelets'] = 6
    dataset.loc[(dataset['platelets'] > 400000) & (dataset['platelets'] <= 500000), 'platelets'] = 7
    dataset.loc[ dataset['platelets'] > 500000, 'platelets'] = 8

# %%
bar_chart('platelets')

# %%
train.head()
# Out:
#    age  anaemia  creatinine_phosphokinase  ...  smoking  time  DEATH_EVENT
# 0  5.0        0                        11  ...        0     4            1
# 1  3.0        0                        13  ...        0     6            1
# 2  4.0        0                         5  ...        1     7            1
# 3  2.0        1                         4  ...        0     7            1
# 4  4.0        1                         5  ...        0     8            1
#
# [5 rows x 13 columns]

# %%
bar_chart('ejection_fraction')

# %% [markdown]
# catagorised ejection_fraction

# %%
facet = sns.FacetGrid(train, hue="DEATH_EVENT",aspect=4)
facet.map(sns.kdeplot,'ejection_fraction',shade= True)
facet.set(xlim=(0, train['ejection_fraction'].max()))
facet.add_legend()
plt.show()

# %%
train_test_data = [train]
for dataset in train_test_data:
    dataset.loc[ dataset['ejection_fraction'] <= 14, 'ejection_fraction'] = 0
    dataset.loc[(dataset['ejection_fraction'] > 14) & (dataset['ejection_fraction'] <= 20), 'ejection_fraction'] = 1
    dataset.loc[(dataset['ejection_fraction'] > 20) & (dataset['ejection_fraction'] <= 30), 'ejection_fraction'] = 2
    dataset.loc[(dataset['ejection_fraction'] > 30) & (dataset['ejection_fraction'] <= 40), 'ejection_fraction'] = 3
    dataset.loc[(dataset['ejection_fraction'] > 40) & (dataset['ejection_fraction'] <= 50), 'ejection_fraction'] = 4
    dataset.loc[(dataset['ejection_fraction'] > 50) & (dataset['ejection_fraction'] <= 60), 'ejection_fraction'] = 5
    dataset.loc[(dataset['ejection_fraction'] > 60) & (dataset['ejection_fraction'] <= 70), 'ejection_fraction'] = 6
    dataset.loc[ dataset['ejection_fraction'] > 70, 'ejection_fraction'] = 7

# %%
bar_chart('ejection_fraction')

# %%
train.head()
# Out:
#    age  anaemia  creatinine_phosphokinase  ...  smoking  time  DEATH_EVENT
# 0  5.0        0                        11  ...        0     4            1
# 1  3.0        0                        13  ...        0     6            1
# 2  4.0        0                         5  ...        1     7            1
# 3  2.0        1                         4  ...        0     7            1
# 4  4.0        1                         5  ...        0     8            1
#
# [5 rows x 13 columns]

# %% [markdown]
# **Catagorised serum_creatinine**

# %%
bar_chart('serum_creatinine')

# %%
facet = sns.FacetGrid(train, hue="DEATH_EVENT",aspect=4)
facet.map(sns.kdeplot,'serum_creatinine',shade= True)
facet.set(xlim=(0, train['serum_creatinine'].max()))
facet.add_legend()
plt.show()

# %%
train_test_data = [train]
for dataset in train_test_data:
    dataset.loc[ dataset['serum_creatinine'] <= 0.5, 'serum_creatinine'] = 0
    dataset.loc[(dataset['serum_creatinine'] > 0.5) & (dataset['serum_creatinine'] <= .75), 'serum_creatinine'] = 1
    dataset.loc[(dataset['serum_creatinine'] > .75) & (dataset['serum_creatinine'] <= 1.0), 'serum_creatinine'] = 2
    dataset.loc[(dataset['serum_creatinine'] > 1.25) & (dataset['serum_creatinine'] <= 1.5), 'serum_creatinine'] = 3
    dataset.loc[(dataset['serum_creatinine'] > 1.5) & (dataset['serum_creatinine'] <= 1.75), 'serum_creatinine'] = 4
    dataset.loc[(dataset['serum_creatinine'] > 1.75) & (dataset['serum_creatinine'] <= 2.4), 'serum_creatinine'] = 5
    dataset.loc[(dataset['serum_creatinine'] > 2.4) & (dataset['serum_creatinine'] <= 3), 'serum_creatinine'] = 6
    dataset.loc[(dataset['serum_creatinine'] > 3.5) & (dataset['serum_creatinine'] <= 4.5), 'serum_creatinine'] = 7
    dataset.loc[ dataset['serum_creatinine'] > 4.5, 'serum_creatinine'] = 8

# %%
bar_chart('serum_creatinine')

# %%
train.head()
# Out:
#    age  anaemia  creatinine_phosphokinase  ...  smoking  time  DEATH_EVENT
# 0  5.0        0                        11  ...        0     4            1
# 1  3.0        0                        13  ...        0     6            1
# 2  4.0        0                         5  ...        1     7            1
# 3  2.0        1                         4  ...        0     7            1
# 4  4.0        1                         5  ...        0     8            1
#
# [5 rows x 13 columns]

# %% [markdown]
# **Processing the serum_sodium**

# %%
bar_chart('serum_sodium')

# %%
facet = sns.FacetGrid(train, hue="DEATH_EVENT",aspect=4)
facet.map(sns.kdeplot,'serum_sodium',shade= True)
facet.set(xlim=(0, train['serum_sodium'].max()))
facet.add_legend()
plt.show()

# %%
train_test_data = [train]
for dataset in train_test_data:
    dataset.loc[ dataset['serum_sodium'] <= 115, 'serum_sodium'] = 0
    dataset.loc[(dataset['serum_sodium'] > 115) & (dataset['serum_sodium'] <= 120), 'serum_sodium'] = 1
    dataset.loc[(dataset['serum_sodium'] > 120) & (dataset['serum_sodium'] <= 125), 'serum_sodium'] = 2
    dataset.loc[(dataset['serum_sodium'] > 125) & (dataset['serum_sodium'] <= 130), 'serum_sodium'] = 3
    dataset.loc[(dataset['serum_sodium'] > 130) & (dataset['serum_sodium'] <= 135), 'serum_sodium'] = 4
    dataset.loc[(dataset['serum_sodium'] > 135) & (dataset['serum_sodium'] <= 140), 'serum_sodium'] = 5
    dataset.loc[(dataset['serum_sodium'] > 140) & (dataset['serum_sodium'] <= 150), 'serum_sodium'] = 6
    dataset.loc[ dataset['serum_creatinine'] > 150, 'serum_sodium'] = 7

# %%
bar_chart('serum_sodium')

# %%
train.head()
# Out:
#    age  anaemia  creatinine_phosphokinase  ...  smoking  time  DEATH_EVENT
# 0  5.0        0                        11  ...        0     4            1
# 1  3.0        0                        13  ...        0     6            1
# 2  4.0        0                         5  ...        1     7            1
# 3  2.0        1                         4  ...        0     7            1
# 4  4.0        1                         5  ...        0     8            1
#
# [5 rows x 13 columns]

# %% [markdown]
# **Processing time**

# %%
bar_chart('time')

# %%
facet = sns.FacetGrid(train, hue="DEATH_EVENT",aspect=4)
facet.map(sns.kdeplot,'time',shade= True)
facet.set(xlim=(0, train['time'].max()))
facet.add_legend()
plt.show()

# %%
train_test_data = [train]
for dataset in train_test_data:
    dataset.loc[ dataset['time'] <= 25, 'time'] = 0
    dataset.loc[(dataset['time'] > 25) & (dataset['time'] <= 50), 'time'] = 1
    dataset.loc[(dataset['time'] > 50) & (dataset['time'] <= 75), 'time'] = 2
    dataset.loc[(dataset['time'] > 75) & (dataset['time'] <= 100), 'time'] = 3
    dataset.loc[(dataset['time'] > 100) & (dataset['time'] <= 150), 'time'] = 4
    dataset.loc[(dataset['time'] > 150) & (dataset['time'] <= 200), 'time'] = 5
    dataset.loc[(dataset['time'] > 200) & (dataset['time'] <= 250), 'time'] = 6
    dataset.loc[ dataset['time'] > 250, 'time'] = 7

# %%
bar_chart('time')

# %%
train.head()
# Out:
#    age  anaemia  creatinine_phosphokinase  ...  smoking  time  DEATH_EVENT
# 0  5.0        0                        11  ...        0     0            1
# 1  3.0        0                        13  ...        0     0            1
# 2  4.0        0                         5  ...        1     0            1
# 3  2.0        1                         4  ...        0     0            1
# 4  4.0        1                         5  ...        0     0            1
#
# [5 rows x 13 columns]

# %% [markdown]
# **Dividing the dataset**

# %%
# (X_TRAIN->train_data, Y_TRAIN->target), X_TEST, Y_TEST
train_data = train.drop('DEATH_EVENT', axis=1)     
target = train['DEATH_EVENT']

train_data.shape, target.shape
# Out:
# ((299, 12), (299,))

# %% [markdown]
# **Splitting the dataset into train and test data**

# %%
from sklearn.model_selection import train_test_split

predictors = dataset.drop("DEATH_EVENT",axis=1)
target = dataset["DEATH_EVENT"]

X_train,X_test,Y_train,Y_test = train_test_split(predictors,target,test_size=0.20,random_state=0)
print("X_train: ", X_train.shape)
print("X_test: ", X_test.shape)
print("Y_train: ", Y_train.shape)
print("Y_test: ", Y_test.shape)
print(Y_test)

Y_test.value_counts()
# Out:
# X_train:  (239, 12)
# X_test:  (60, 12)
# Y_train:  (239,)
# Y_test:  (60,)
# 206    0
# 188    0
# 12     1
# 219    0
# 237    0
# 136    0
# 228    0
# 205    0
# 52     1
# 108    0
# 240    0
# 15     1
# 184    1
# 246    1
# 22     1
# 74     1
# 269    0
# 90     0
# 227    0
# 255    0
# 190    0
# 103    0
# 124    1
# 129    0
# 220    1
# 116    0
# 194    1
# 285    0
# 294    0
# 249    0
# 92     0
# 66     1
# 8      1
# 122    0
# 217    1
# 150    1
# 176    0
# 182    1
# 298    0
# 5      1
# 263    0
# 89     0
# 81     0
# 34     1
# 55     1
# 139    0
# 234    0
# 64     0
# 7      1
# 45     1
# 73     0
# 291    0
# 173    0
# 106    0
# 59     1
# 230    1
# 168    0
# 26     1
# 283    0
# 153    0
# Name: DEATH_EVENT, dtype: int64
# 0    37
# 1    23
# Name: DEATH_EVENT, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# **Train the dataset**

# %% [markdown]
# **Decision Tree**

# %%
from sklearn.tree import DecisionTreeClassifier

max_accuracy = 0


for x in range(200):
    dt = DecisionTreeClassifier(random_state=x)
    dt.fit(X_train,Y_train)
    Y_pred_dt = dt.predict(X_test)
    current_accuracy = round(accuracy_score(Y_pred_dt,Y_test)*100,2)
    if(current_accuracy>max_accuracy):
        max_accuracy = current_accuracy
        best_x = x
        
#print(max_accuracy)
#print(best_x)


dt = DecisionTreeClassifier(random_state=best_x)
dt.fit(X_train,Y_train)
Y_pred_dt = dt.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report
print(confusion_matrix(Y_pred_dt,Y_test))
print(classification_report(Y_pred_dt,Y_test))
# Out:
# [[34  8]
#  [ 3 15]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.81      0.86        42
#            1       0.65      0.83      0.73        18
#
#     accuracy                           0.82        60
#    macro avg       0.79      0.82      0.80        60
# weighted avg       0.84      0.82      0.82        60

# %%
from sklearn.metrics import accuracy_score
score_dt = round(accuracy_score(Y_pred_dt,Y_test)*100,2)

print("The accuracy score achieved using Decision Tree is: "+str(score_dt)+" %")
# Out:
# The accuracy score achieved using Decision Tree is: 81.67 %

# %% [markdown]
# SVM

# %%
from sklearn import svm

sv = svm.SVC(kernel='linear')

sv.fit(X_train, Y_train)

Y_pred_svm = sv.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report
print(confusion_matrix(Y_pred_dt,Y_test))
print(classification_report(Y_pred_dt,Y_test))
# Out:
# [[34  8]
#  [ 3 15]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.81      0.86        42
#            1       0.65      0.83      0.73        18
#
#     accuracy                           0.82        60
#    macro avg       0.79      0.82      0.80        60
# weighted avg       0.84      0.82      0.82        60

# %%
Y_pred_svm.shape
# Out:
# (60,)

# %%
score_svm = round(accuracy_score(Y_pred_svm,Y_test)*100,2)

print("The accuracy score achieved using Linear SVM is: "+str(score_svm)+" %")
# Out:
# The accuracy score achieved using Linear SVM is: 81.67 %

# %% [markdown]
# **Naive Bayes**

# %%
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()

nb.fit(X_train,Y_train)

Y_pred_nb = nb.predict(X_test)

# %%
Y_pred_nb.shape
# Out:
# (60,)

# %%
from sklearn.metrics import confusion_matrix,classification_report
print(confusion_matrix(Y_pred_dt,Y_test))
print(classification_report(Y_pred_dt,Y_test))
# Out:
# [[34  8]
#  [ 3 15]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.81      0.86        42
#            1       0.65      0.83      0.73        18
#
#     accuracy                           0.82        60
#    macro avg       0.79      0.82      0.80        60
# weighted avg       0.84      0.82      0.82        60

# %%
from sklearn.metrics import confusion_matrix,classification_report
print(confusion_matrix(Y_pred_dt,Y_test))
print(classification_report(Y_pred_dt,Y_test))
# Out:
# [[34  8]
#  [ 3 15]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.81      0.86        42
#            1       0.65      0.83      0.73        18
#
#     accuracy                           0.82        60
#    macro avg       0.79      0.82      0.80        60
# weighted avg       0.84      0.82      0.82        60

# %%
score_nb = round(accuracy_score(Y_pred_nb,Y_test)*100,2)

print("The accuracy score achieved using Naive Bayes is: "+str(score_nb)+" %")
# Out:
# The accuracy score achieved using Naive Bayes is: 83.33 %

# %% [markdown]
# **logistic regression**

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()

lr.fit(X_train,Y_train)

Y_pred_lr = lr.predict(X_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,

# %%
Y_pred_lr.shape
# Out:
# (60,)

# %%
score_lr = round(accuracy_score(Y_pred_lr,Y_test)*100,2)

print("The accuracy score achieved using Logistic Regression is: "+str(score_lr)+" %")
# Out:
# The accuracy score achieved using Logistic Regression is: 81.67 %

# %% [markdown]
# **Random Forest**

# %%
from sklearn.ensemble import RandomForestClassifier


rf = RandomForestClassifier()
rf.fit(X_train,Y_train)
Y_pred_rf = rf.predict(X_test)

# %%
y_pred.shape
# Out:
# (60,)

# %%
score_rf = round(accuracy_score(y_pred,Y_test)*100,2)

print("The accuracy score achieved using Decision Tree is: "+str(score_rf)+" %")
# Out:
# The accuracy score achieved using Decision Tree is: 78.33 %

# %% [markdown]
# **Comparing the Results**

# %%
scores = [score_lr,score_nb,score_svm,score_dt,score_rf]
algorithms = ["Logistic Regression","Naive Bayes","Support Vector Machine","Decision Tree","Random Forest"]    

for i in range(len(algorithms)):
    print("The accuracy score achieved using "+algorithms[i]+" is: "+str(scores[i])+" %")
# Out:
# The accuracy score achieved using Logistic Regression is: 81.67 %
# The accuracy score achieved using Naive Bayes is: 83.33 %
# The accuracy score achieved using Support Vector Machine is: 81.67 %
# The accuracy score achieved using Decision Tree is: 81.67 %
# The accuracy score achieved using Random Forest is: 78.33 %

# %%
sns.set(rc={'figure.figsize':(15,8)})
plt.xlabel("Algorithms")
plt.ylabel("Accuracy score")

sns.barplot(algorithms,scores)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
